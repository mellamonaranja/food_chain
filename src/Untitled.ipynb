# %%
from dataC import DataConnector

# %%
from glob import glob
files = glob("../data/dataset/supply_chain/*.xls")

# %%
help(DataConnector)
# Out:
# Help on class DataConnector in module readDataCopy:
#
# class DataConnector(builtins.object)
#  |  DataConnector(files: str)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, files: str)
#  |      return
#  |
#  |  df_preprocess(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
connection=DataConnector(files)
df=connection.df_preprocess()
df.head()
# DataConnector(files).df_preprocess()
# DataConnector(files).df_preprocess()
# Out:
# Connecting
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (6693331) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#         day    customer       code                             품목명  \
# 0  20200201  군산봉정요양병원**  1042594.0  (직) 세척당근 kg(생 2L 250~300g 중국산)
# 1  20200201  군산봉정요양병원**  1028277.0              (직) 흙대파 kg(생 끝 절단)
# 2  20200201  군산봉정요양병원**  1004327.0     *요구르트 65ml(라이트 한국야쿠르트 냉장)..
# 3  20200201  군산봉정요양병원**  1049419.0            *)참기름 1.8L(쉐프초이스 신송)
# 4  20200201  군산봉정요양병원**  1038658.0                *)미향 1.8L(오뚜기)..
#
#             원산지  quantity    price    sum
# 0           중국산       3.0   1050.0   3150
# 1           국내산       2.0   1950.0   3900
# 2           국내산     110.0     90.0   9900
# 3  수입산(참깨분100％)       1.0  13490.0  13490
# 4            국내       1.0   3050.0   3050

# %%
df
# Out:
#             day    customer       code                              품목명  \
# 0      20200201  군산봉정요양병원**  1042594.0   (직) 세척당근 kg(생 2L 250~300g 중국산)
# 1      20200201  군산봉정요양병원**  1028277.0               (직) 흙대파 kg(생 끝 절단)
# 2      20200201  군산봉정요양병원**  1004327.0      *요구르트 65ml(라이트 한국야쿠르트 냉장)..
# 3      20200201  군산봉정요양병원**  1049419.0             *)참기름 1.8L(쉐프초이스 신송)
# 4      20200201  군산봉정요양병원**  1038658.0                 *)미향 1.8L(오뚜기)..
# ...         ...         ...        ...                              ...
# 33536  20201130   xx늘푸른요양병원  1028336.0                   (직) 팽이버섯 kg(생)
# 33537  20201130   xx늘푸른요양병원  1050467.0                *)자숙바지락살 250g(냉동)
# 33538  20201130   xx늘푸른요양병원  1087500.0       (NH) 홍새우살 200g(200/300 냉동)
# 33540  20201130   xx늘푸른요양병원  1087488.0               (직) 세발나물 박스 4kg(생)
# 33541  20201130   xx늘푸른요양병원  1092521.0  효사랑전용>(할인)면장갑 묶음(10ea 초록두줄 천일표)
#
#                 원산지  quantity    price    sum
# 0               중국산       3.0   1050.0   3150
# 1               국내산       2.0   1950.0   3900
# 2               국내산     110.0     90.0   9900
# 3      수입산(참깨분100％)       1.0  13490.0  13490
# 4                국내       1.0   3050.0   3050
# ...             ...       ...      ...    ...
# 33536           국내산       2.0   2940.0   5880
# 33537           중국산       9.0   1600.0  14400
# 33538           중국산       4.0   2540.0  10160
# 33540           국내산       1.0  14300.0  14300
# 33541          국내제조       1.0   5500.0   5500
#
# [857497 rows x 8 columns]
